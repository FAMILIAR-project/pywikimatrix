# %%
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt

# Open Website and get only the table on the page with the relevant data. In this hardcoded case 

def get_wikipedia_html(url):
    return urllib.request.urlopen(url).read().decode("utf-8") # TODO exceptions

whtml = get_wikipedia_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies#S.26P_500_Component_Stocks")

# first table of the HTML (there may be more than one!)
# header=0 means that the first row is used as a header 
df = pd.read_html(whtml, header=0)[0] 

plt.figure()
pd.to_numeric(df["Founded"], errors="coerce").plot.box()
plt.show()

plt.figure()
df["GICS Sector"].value_counts().plot.bar() # or pie()
plt.show()

# %%
with open("list_of_PCMs.txt") as f:
    wurls = f.readlines()
BASE_WIKIPEDIA_URL="https://en.wikipedia.org/wiki/"

cols_stats = ["URL", "nrows", "ncols"]
df_stats = pd.DataFrame(columns=cols_stats)
    
for wurl in wurls:    
    print ("Extracting from", wurl)
    try:
        wfurl = BASE_WIKIPEDIA_URL + wurl
        whtml = get_wikipedia_html(wfurl)
        
        # TODO there may be more than one table
        # TODO header=0 means that the first row is used as a header, but it can be different 
        # TODO there are other ways to process the HTML (but pandas facilities sound great!)
        df = pd.read_html(whtml, header=0)[0]
        
        print (df.shape)
        vals = [wurl, df.shape[0], df.shape[1]]
        df_stats = df_stats.append(dict(zip(cols_stats, vals)), ignore_index=True)
    except urllib.request.HTTPError: 
        print ("URL is not valid!")
    except UnicodeEncodeError:
        print ("ASCII decoding error")
# Out:
# Extracting from Comparison_between_Esperanto_and_Ido
#
# (4, 6)
# Extracting from Comparison_between_Esperanto_and_Interlingua
#
# (4, 6)
# Extracting from Comparison_between_Esperanto_and_Novial
#
# (0, 2)
# Extracting from Comparison_between_Ido_and_Interlingua
#
# (0, 2)
# Extracting from Comparison_between_Ido_and_Novial
#
# (0, 2)
# Extracting from Comparison_between_U.S._states_and_countries_by_GDP_(PPP)
#
# (51, 4)
# Extracting from Comparison_of_ALGOL_68_and_C++
#
# (0, 2)
# Extracting from Comparison_of_Afrikaans_and_Dutch
#
# (187, 3)
# Extracting from Comparison_of_Android_e-book_reader_software
#
# (16, 4)
# Extracting from Comparison_of_Asian_national_space_programs
#
# (0, 7)
# Extracting from Comparison_of_Axis_&_Allies_games
#
# (4, 6)
# Extracting from Comparison_of_C_Sharp_and_Visual_Basic_.NET
#
# (5, 1)
# Extracting from Comparison_of_Chernobyl_and_other_radioactivity_releases
#
# (0, 2)
# Extracting from Comparison_of_Exchange_ActiveSync_clients
#
# URL is not valid!
# Extracting from Comparison_of_Hokkien_writing_systems
#
# (28, 1)
# Extracting from Comparison_of_Home_Owners'_and_Civic_Associations
#
# (4, 6)
# Extracting from Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes
#
# (0, 2)
# Extracting from Comparison_of_Java_and_C++
#
# (10, 12)
# Extracting from Comparison_of_Linux_distributions
#
# (4, 6)
# Extracting from Comparison_of_MD_and_DO_in_the_United_States
#
# (4, 6)
# Extracting from Comparison_of_Norwegian_Bokmål_and_Standard_Danish
#
# ASCII decoding error
# Extracting from Comparison_of_Portuguese_and_Spanish
#
# (0, 2)
# Extracting from Comparison_of_Symbian_devices
#
# (0, 2)
# Extracting from Comparison_of_United_States_presidential_candidates,_2008
#
# (16, 4)
# Extracting from Comparison_of_World_War_I_tanks
#
# (0, 2)
# Extracting from Comparison_of_browser_synchronizers
#
# (31, 16)
# Extracting from Comparison_of_business_integration_software
#
# (34, 8)
# Extracting from Comparison_of_consumer_brain–computer_interfaces
#
# ASCII decoding error
# Extracting from Comparison_of_domestic_robots
#
# (0, 2)
# Extracting from Comparison_of_e-book_formats
#
# (1, 2)
# Extracting from Comparison_of_e-book_readers
#
# (59, 20)
# Extracting from Comparison_of_file_hosting_services
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(Cascading_Style_Sheets)
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(MathML)
#
# URL is not valid!
# Extracting from Comparison_of_machine_translation_applications
#
# (14, 1)
# Extracting from Comparison_of_mobile_operating_systems
#
# (0, 6)
# Extracting from Comparison_of_network_diagram_software
#
# (0, 2)
# Extracting from Comparison_of_numerical_analysis_software
#
# (39, 9)
# Extracting from Comparison_of_privilege_authorization_features
#
# (1, 2)
# Extracting from Comparison_of_programming_languages_(object-oriented_programming)
#
# (0, 2)
# Extracting from Comparison_of_programming_languages_(string_functions)
#
# (5, 1)
# Extracting from Comparison_of_relational_database_management_systems
#
# (61, 7)
# Extracting from Comparison_(grammar)
#
# (0, 2)
# Extracting from Comparison_between_Argentine_provinces_and_countries_by_GDP_(PPP)_per_capita
#
# (207, 3)
# Extracting from Comparison_between_U.S._states_and_countries_by_GDP_(nominal)
#
# (981, 1473)
# Extracting from Comparison_between_U.S._states_and_countries_by_GDP_(nominal)_per_capita
#
# (2, 1)
# Extracting from Comparison_of_401(k)_and_IRA_accounts
#
# (21, 5)
# Extracting from Comparison_of_ADO_and_ADO.NET
#
# URL is not valid!
# Extracting from Comparison_of_AMD_CPU_microarchitectures
#
# (7, 3)
# Extracting from Comparison_of_American_and_British_English
#
# (8, 10)
# Extracting from List_of_BPEL_engines
#
# (13, 7)
# Extracting from Comparison_of_BitTorrent_tracker_software
#
# (8, 7)
# Extracting from Comparison_of_Business_Process_Modeling_Notation_tools
#
# (23, 9)
# Extracting from Comparison_of_CAD,_CAM_and_CAE_file_viewers
#
# (5, 10)
# Extracting from Comparison_of_CRT,_LCD,_Plasma,_and_OLED
#
# (4, 6)
# Extracting from Comparison_of_California_ski_resorts
#
# (28, 11)
# Extracting from Comparison_of_Canadian-tax_preparation_software_for_personal_use
#
# URL is not valid!
# Extracting from Comparison_of_Chinese_romanization_systems
#
# (28, 1)
# Extracting from Comparison_of_Colorado_ski_resorts
#
# (4, 6)
# Extracting from Comparison_of_DNS_blacklists
#
# (68, 9)
# Extracting from Comparison_of_Dewey_and_Library_of_Congress_subject_classification
#
# (456, 3)
# Extracting from Comparison_of_H.264_and_VC-1
#
# (4, 3)
# Extracting from Comparison_of_HP_graphing_calculators
#
# (23, 14)
# Extracting from Comparison_of_HTML5_and_Flash
#
# (32, 4)
# Extracting from Comparison_of_HTML_parsers
#
# (4, 6)
# Extracting from Comparison_of_IPv6_application_support
#
# URL is not valid!
# Extracting from Comparison_of_IPv6_support_by_major_transit_providers
#
# URL is not valid!
# Extracting from Comparison_of_IPv6_support_in_operating_systems
#
# (35, 7)
# Extracting from Comparison_of_IPv6_support_in_routers
#
# URL is not valid!
# Extracting from Comparison_of_Intel_processors
#
# (0, 2)
# Extracting from Comparison_of_Internet_Relay_Chat_bots
#
# (0, 2)
# Extracting from Comparison_of_Lemmings_ports
#
# (11, 2)
# Extracting from Comparison_of_MIDI_standards
#
# (17, 10)
# Extracting from Comparison_of_Malaysian_and_Indonesian
#
# (593, 4)
# Extracting from Comparison_of_MySQL_database_engines
#
# (0, 2)
# Extracting from Comparison_of_net-connected_media_players
#
# (5, 15)
# Extracting from Comparison_of_Office_Open_XML_and_OpenDocument
#
# (31, 3)
# Extracting from Comparison_of_OpenGL_and_Direct3D
#
# (6, 8)
# Extracting from Comparison_of_OpenXPS_and_PDF
#
# (39, 3)
# Extracting from Comparison_of_PSA_systems
#
# (10, 7)
# Extracting from Comparison_of_Power_Management_Software_Suites
#
# (17, 6)
# Extracting from Comparison_of_S.M.A.R.T._tools
#
# (0, 2)
# Extracting from Comparison_of_Scottish_Gaelic_and_Irish
#
# (0, 2)
# Extracting from Comparison_of_Skype_recorders
#
# URL is not valid!
# Extracting from Comparison_of_TeX_editors
#
# (23, 9)
# Extracting from Comparison_of_Toyota_hybrids
#
# (6, 8)
# Extracting from Comparison_of_Tryton_and_Open_ERP
#
# URL is not valid!
# Extracting from Comparison_of_US_and_Chinese_Military_Armed_Forces
#
# (4, 6)
# Extracting from Comparison_of_VMware_Fusion_and_Parallels_Desktop
#
# (0, 2)
# Extracting from Comparison_of_Vector_Formats_(GIS)
#
# (10, 3)
# Extracting from Comparison_of_Windows_Vista_and_Windows_XP
#
# (0, 2)
# Extracting from Comparison_of_X_window_managers
#
# (39, 14)
# Extracting from Comparison_of_agent-based_modeling_software
#
# (21, 10)
# Extracting from Comparison_of_anaerobic_and_aerobic_digestion
#
# (4, 2)
# Extracting from Comparison_of_application_servers
#
# (4, 6)
# Extracting from Comparison_of_archive_formats
#
# (0, 2)
# Extracting from Comparison_of_baseball_and_softball
#
# (26, 4)
# Extracting from Comparison_of_behavioral_experiment_software
#
# URL is not valid!
# Extracting from Comparison_of_birth_control_methods
#
# (5, 3)
# Extracting from Comparison_of_chess_video_games
#
# (4, 6)
# Extracting from Comparison_of_cognitive_architectures
#
# (22, 10)
# Extracting from Comparison_of_continuous_integration_software
#
# (4, 6)
# Extracting from Comparison_of_cricket_and_baseball
#
# (4, 6)
# Extracting from Comparison_of_crowd_funding_services
#
# (0, 2)
# Extracting from Comparison_of_dance_video_games
#
# (0, 2)
# Extracting from Comparison_of_debuggers
#
# (10, 9)
# Extracting from Comparison_of_defragmentation_software
#
# (0, 2)
# Extracting from Comparison_of_dental_practice_management_software
#
# (0, 2)
# Extracting from Comparison_of_development_estimation_software
#
# (7, 3)
# Extracting from Comparison_of_disc_image_software
#
# (0, 2)
# Extracting from Comparison_of_display_technology
#
# (31, 6)
# Extracting from Comparison_of_distributed_file_systems
#
# (17, 4)
# Extracting from Comparison_of_document_interfaces
#
# (0, 2)
# Extracting from Comparison_of_document_markup_languages
#
# (30, 5)
# Extracting from Comparison_of_educational_websites_for_children
#
# URL is not valid!
# Extracting from Comparison_of_embedded_computer_systems_on_board_the_Mars_rovers
#
# (5, 7)
# Extracting from Comparison_of_executable_file_formats
#
# (29, 12)
# Extracting from Comparison_of_facial_image_datasets
#
# (14, 1)
# Extracting from Comparison_of_free_credit_report_websites
#
# (19, 5)
# Extracting from Comparison_of_free_software_e-commerce_web_application_frameworks
#
# (4, 6)
# Extracting from Comparison_of_general_and_generalized_linear_models
#
# (0, 2)
# Extracting from Comparison_of_hardware_random_number_generators
#
# URL is not valid!
# Extracting from Comparison_of_help_desk_issue_tracking_software
#
# (13, 6)
# Extracting from Comparison_of_high_definition_optical_disc_formats
# (23, 8)
# Extracting from Comparison_of_hub_gears
#
# (35, 11)
# Extracting from Comparison_of_iSCSI_targets
#
# (6, 8)
# Extracting from Comparison_of_karate_styles
#
# (4, 6)
# Extracting from Comparison_of_macro_recorder_software
#
# URL is not valid!
# Extracting from Comparison_of_mobile_phone_standards
#
# (0, 2)
# Extracting from Comparison_of_neurofeedback_software
#
# (0, 2)
# Extracting from Comparison_of_object-relational_mapping_software
#
# (25, 6)
# Extracting from Comparison_of_object_database_management_systems
#
# (16, 7)
# Extracting from Comparison_of_online_charity_donation_services_in_the_United_Kingdom
#
# (7, 6)
# Extracting from Comparison_of_online_dating_websites
#
# (39, 9)
# Extracting from Comparison_of_online_music_lockers
#
# (19, 8)
# Extracting from Comparison_of_optimization_software
#
# (0, 2)
# Extracting from Comparison_of_packet_analyzers
#
# (27, 6)
# Extracting from Comparison_of_popular_optical_data-storage_systems
#
# (5, 2)
# Extracting from Comparison_of_programming_languages_(strings)
#
# (0, 2)
# Extracting from Comparison_of_programming_languages_(syntax)
#
# (0, 2)
# Extracting from Comparison_of_programming_paradigms
#
# (4, 6)
# Extracting from Comparison_of_radio_systems
#
# (0, 2)
# Extracting from Comparison_of_real_estate_websites
#
# URL is not valid!
# Extracting from Comparison_of_12-13.3_inch_subnotebooks
#
# URL is not valid!
# Extracting from Comparison_of_3D_computer_graphics_software
#
# (0, 2)
# Extracting from Comparison_of_AMD_processors
#
# (166, 16)
# Extracting from Comparison_of_Adobe_Flex_charts
#
# (38, 13)
# Extracting from Comparison_of_BitTorrent_sites
#
# (20, 1)
# Extracting from Comparison_of_instruction_set_architectures
#
# (38, 14)
# Extracting from Comparison_of_CRM_systems
#
# (28, 9)
# Extracting from Comparison_of_CalDAV_and_CardDAV_implementations
#
# (20, 11)
# Extracting from Comparison_of_Canon_EOS_digital_cameras
#
# (63, 18)
# Extracting from Comparison_of_DEX_software
#
# (5, 19)
# Extracting from Comparison_of_DOS_operating_systems
#
# (54, 5)
# Extracting from Comparison_of_European_traffic_laws
#
# (46, 16)
# Extracting from Comparison_of_Fukushima_and_Chernobyl_nuclear_accidents
#
# (17, 3)
# Extracting from Comparison_of_ICBMs
#
# (53, 12)
# Extracting from Comparison_of_Internet_forum_software
#
# (0, 2)
# Extracting from Comparison_of_JavaScript-based_source_code_editors
#
# (18, 9)
# Extracting from Comparison_of_JavaScript_charting_frameworks
#
# (0, 2)
# Extracting from Comparison_of_Java_Remote_Desktop_projects
#
# (9, 12)
# Extracting from Comparison_of_Nikon_DSLR_cameras
#
# (50, 28)
# Extracting from Comparison_of_Nintendo_portable_consoles
#
# (33, 15)
# Extracting from Comparison_of_North_American_ski_resorts
#
# (4, 6)
# Extracting from Comparison_of_Solaris_distributions
#
# (8, 8)
# Extracting from Comparison_of_Subversion_clients
#
# (0, 2)
# Extracting from Comparison_of_Texas_Instruments_graphing_calculators
#
# (21, 12)
# Extracting from Comparison_of_UPnP_AV_media_servers
#
# (48, 16)
# Extracting from Comparison_of_Unicode_encodings
#
# (8, 6)
# Extracting from Comparison_of_United_Kingdom_and_United_States_military_ranks
#
# (0, 2)
# Extracting from Comparison_of_Usenet_newsreaders
#
# (0, 2)
# Extracting from Comparison_of_WebSocket_implementations
#
# (6, 8)
# Extracting from Comparison_of_XML_editors
#
# (24, 19)
# Extracting from Comparison_of_XMPP_server_software
#
# (12, 12)
# Extracting from Comparison_of_application_virtualization_software
#
# (0, 2)
# Extracting from Comparison_of_brainwave_entrainment_software
#
# (0, 2)
# Extracting from Comparison_of_code_generation_tools
#
# (4, 6)
# Extracting from Comparison_of_color_models_in_computer_graphics
#
# (0, 2)
# Extracting from Comparison_of_cryptographic_hash_functions
#
# (19, 5)
# Extracting from Comparison_of_data_modeling_tools
#
# (19, 8)
# Extracting from Comparison_of_disk_cloning_software
#
# (0, 2)
# Extracting from Comparison_of_dosimeters
#
# (16, 16)
# Extracting from Comparison_of_early_World_War_II_tanks
#
# (3, 2)
# Extracting from Comparison_of_early_word_processors
#
# (23, 16)
# Extracting from Comparison_of_encrypted_external_drives
#
# (18, 4)
# Extracting from Comparison_of_file_sharing_applications
#
# (53, 11)
# Extracting from Comparison_of_free_and_open-source_software_licenses
#
# (40, 11)
# Extracting from Comparison_of_free_web_hosting_services
#
# (0, 2)
# Extracting from Comparison_of_graphics_file_formats
#
# (243, 8)
# Extracting from Comparison_of_handheld_game_consoles
#
# (0, 2)
# Extracting from Comparison_of_instant_messaging_protocols
#
# (24, 19)
# Extracting from Comparison_of_layout_engines_(HTML5_canvas)
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(HTML5_media)
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(XHTML)
#
# (4, 1)
# Extracting from Comparison_of_layout_engines_(web_typography)
#
# URL is not valid!
# Extracting from Comparison_of_web_server_software
#
# (38, 5)
# Extracting from Comparison_of_linear_algebra_libraries
#
# (0, 2)
# Extracting from Comparison_of_netbook-oriented_Linux_distributions
#
# (23, 16)
# Extracting from Comparison_of_object-relational_database_management_systems
#
# (0, 2)
# Extracting from Comparison_of_online_music_stores
#
# (22, 16)
# Extracting from Comparison_of_open-source_configuration_management_software
#
# (0, 2)
# Extracting from Comparison_of_optical_character_recognition_software
#
# (35, 16)
# Extracting from Comparison_of_orbital_launch_systems
#
# (106, 9)
# Extracting from Comparison_of_orbital_launchers_families
#
# (78, 16)
# Extracting from Comparison_of_orbital_rocket_engines
#
# (0, 2)
# Extracting from Comparison_of_personal_air_vehicles
#
# (2, 7)
# Extracting from Comparison_of_programming_languages
#
# (5, 1)
# Extracting from Comparison_of_programming_languages_(array)
#
# (0, 2)
# Extracting from Comparison_of_project_management_software
#
# (0, 2)
# Extracting from Comparison_of_BSD_operating_systems
#
# (39, 10)
# Extracting from Comparison_of_DNS_server_software
#
# (25, 13)
# Extracting from Comparison_of_EDA_software
#
# (4, 6)
# Extracting from Comparison_of_English_dictionaries
#
# (10, 9)
# Extracting from Comparison_of_JavaScript_frameworks
#
# (0, 2)
# Extracting from Comparison_of_LAN_messengers
#
# (9, 8)
# Extracting from Comparison_of_MUD_clients
#
# (32, 8)
# Extracting from Comparison_of_Office_Open_XML_software
#
# (0, 2)
# Extracting from Comparison_of_research_networking_tools_and_research_profiling_systems
#
# (54, 5)
# Extracting from Comparison_of_X_Window_System_desktop_environments
#
# (0, 2)
# Extracting from Comparison_of_ad_servers
#
# (0, 2)
# Extracting from Comparison_of_assemblers
#
# (7, 4)
# Extracting from Comparison_of_cluster_software
#
# (28, 10)
# Extracting from Comparison_of_quiz_bowl_formats
#
# URL is not valid!
# Extracting from Comparison_of_data_serialization_formats
#
# (0, 2)
# Extracting from Comparison_of_database_access
#
# (4, 6)
# Extracting from Comparison_of_desktop_application_launchers
#
# (0, 2)
# Extracting from Comparison_of_desktop_publishing_software
#
# (21, 5)
# Extracting from Comparison_of_digital_SLRs
#
# (0, 2)
# Extracting from Comparison_of_hex_editors
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(Scalable_Vector_Graphics)
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(graphics)
#
# (7, 3)
# Extracting from Comparison_of_memory_cards
#
# (30, 7)
# Extracting from Comparison_of_metadata_editors
#
# (46, 18)
# Extracting from Comparison_of_network_monitoring_systems
#
# (48, 23)
# Extracting from Comparison_of_notetaking_software
#
# (37, 4)
# Extracting from Comparison_of_online_backup_services
#
# (50, 25)
# Extracting from Comparison_of_operating_systems
#
# (59, 9)
# Extracting from Comparison_of_parser_generators
#
# (0, 2)
# Extracting from Comparison_of_photo_gallery_software
#
# (1, 10)
# Extracting from Comparison_of_proxifiers
#
# URL is not valid!
# Extracting from Comparison_of_regular_expression_engines
#
# (4, 6)
# Extracting from Comparison_of_ATI_chipsets
#
# (12, 11)
# Extracting from Comparison_of_European_road_signs
#
# (0, 2)
# Extracting from Comparison_of_Macintosh_models
#
# (0, 2)
# Extracting from Comparison_of_NMDC_Software
#
# (19, 12)
# Extracting from Comparison_of_OpenDocument_software
#
# (0, 2)
# Extracting from Comparison_of_PVR_software_packages
#
# (18, 10)
# Extracting from Comparison_of_SSH_servers
#
# (6, 6)
# Extracting from Comparison_of_U.S._state_governments
#
# (57, 13)
# Extracting from Comparison_of_VoIP_software
#
# (77, 26)
# Extracting from Comparison_of_YouTube_downloaders
#
# (0, 2)
# Extracting from Comparison_of_audio_synthesis_environments
#
# (6, 8)
# Extracting from Comparison_of_digital_audio_editors
#
# (34, 10)
# Extracting from Comparison_of_disc_authoring_software
# (13, 3)
# Extracting from Comparison_of_disk_encryption_software
#
# (73, 5)
# Extracting from Comparison_of_download_managers
#
# (21, 10)
# Extracting from Comparison_of_eDonkey_software
#
# (8, 10)
# Extracting from Comparison_of_file_comparison_tools
#
# (26, 11)
# Extracting from Comparison_of_file_verification_software
#
# (55, 11)
# Extracting from Comparison_of_firewalls
#
# (22, 4)
# Extracting from Comparison_of_genealogy_software
#
# (26, 11)
# Extracting from Comparison_of_iPod_managers
#
# (4, 6)
# Extracting from Comparison_of_image_viewers
#
# (36, 4)
# Extracting from Comparison_of_layout_engines_(HTML5)
#
# (0, 2)
# Extracting from Comparison_of_layout_engines_(XML)
#
# (8, 2)
# Extracting from Comparison_of_layout_engines_(non-standard_HTML)
#
# (0, 2)
# Extracting from Comparison_of_massively_multiplayer_online_role-playing_games
#
# (0, 2)
# Extracting from Comparison_of_microblogging_services
#
# (12, 8)
# Extracting from Comparison_of_movie_cameras
#
# (29, 7)
# Extracting from Comparison_of_national_standards_of_Chinese
#
# (20, 8)
# Extracting from Comparison_of_netbooks
#
# (0, 2)
# Extracting from Comparison_of_office_suites
#
# (28, 12)
# Extracting from Comparison_of_open-source_software_hosting_facilities
#
# (20, 9)
# Extracting from Comparison_of_photo_stitching_software
#
# (45, 7)
# Extracting from Comparison_of_platform_virtualization_software
#
# (67, 7)
# Extracting from Comparison_of_C_Sharp_and_Java
#
# (10, 12)
# Extracting from Comparison_of_FTP_client_software
#
# (14, 7)
# Extracting from List_of_FTP_server_software
#
# (0, 2)
# Extracting from Comparison_of_Java_virtual_machines
#
# (16, 7)
# Extracting from Comparison_of_OLAP_Servers
#
# (13, 6)
# Extracting from Comparison_of_Prolog_implementations
#
# (21, 15)
# Extracting from Comparison_of_accounting_software
#
# (0, 2)
# Extracting from Comparison_of_audio_formats
#
# (47, 14)
# Extracting from Comparison_of_database_tools
#
# (28, 18)
# Extracting from Comparison_of_documentation_generators
#
# (26, 5)
# Extracting from Comparison_of_fanless_layer_2_switches
#
# URL is not valid!
# Extracting from Comparison_of_feed_aggregators
#
# (0, 2)
# Extracting from Comparison_of_file_synchronization_software
#
# (0, 2)
# Extracting from Comparison_of_issue-tracking_systems
#
# (0, 2)
# Extracting from Comparison_of_mobile_Internet_Relay_Chat_clients
#
# (0, 2)
# Extracting from Comparison_of_raster-to-vector_conversion_software
#
# (16, 7)
# Extracting from Comparison_of_802.15.4_radio_modules
#
# (4, 6)
# Extracting from Comparison_of_AMD_chipsets
#
# (6, 8)
# Extracting from Comparison_of_Internet_Relay_Chat_daemons
#
# (0, 2)
# Extracting from Comparison_of_SSH_clients
#
# (22, 9)
# Extracting from Comparison_of_boot_loaders
#
# (37, 23)
# Extracting from Comparison_of_command_shells
#
# (6, 8)
# Extracting from Comparison_of_container_formats
#
# (0, 2)
# Extracting from Comparison_of_enterprise_bookmarking_platforms
#
# (0, 2)
# Extracting from Comparison_of_file_systems
#
# (97, 5)
# Extracting from Comparison_of_layout_engines_(ECMAScript)
#
# (8, 2)
# Extracting from Comparison_of_pumps
#
# (0, 2)
# Extracting from Comparison_of_reference_management_software
#
# (32, 9)
# Extracting from Comparison_of_ADC_software
#
# (4, 6)
# Extracting from Comparison_of_file_archivers
#
# (33, 6)
# Extracting from Comparison_of_file_managers
#
# (51, 6)
# Extracting from Comparison_of_iOS_e-book_reader_software
#
# (21, 13)
# Extracting from Comparison_of_open-source_wireless_drivers
#
# (0, 2)
# Extracting from Comparison_of_portable_media_players
#
# (0, 2)
# Extracting from Comparison_of_BitTorrent_clients
#
# (44, 12)
# Extracting from Comparison_of_HTML_editors
#
# (41, 5)
# Extracting from Comparison_of_layout_engines_(Document_Object_Model)
#
# (0, 2)
# Extracting from Comparison_of_mail_servers
#
# (44, 18)
# Extracting from Comparison_of_Internet_Relay_Chat_clients
#
# (0, 2)
# Extracting from Comparison_of_Sony_Vaio_laptops
#
# URL is not valid!
# Extracting from Comparison_of_alcopops
#
# (0, 2)
# Extracting from Comparison_of_geographic_information_systems_software
#
# (42, 10)
# Extracting from Comparison_of_instant_messaging_clients
#
# (4, 6)
# Extracting from Comparison_of_raster_graphics_editors
#
# (4, 6)
# Extracting from Comparison_of_Microsoft_Windows_versions
#
# (5, 9)
# Extracting from Comparison_of_audio_player_software
#
# (54, 20)
# Extracting from Comparison_of_layout_engines_(HTML)
#
# (0, 2)
# Extracting from Comparison_of_open-source_operating_systems
#
# (30, 8)
# Extracting from Comparison_of_programming_languages_(basic_instructions)
#
# (0, 2)
# Extracting from List_of_AMD_graphics_processing_units
#
# (22, 16)
# Extracting from Comparison_of_Android_devices
#
# URL is not valid!
# Extracting from List_of_Intel_graphics_processing_units
#
# (7, 17)
# Extracting from Comparison_of_Internet_Relay_Chat_services
#
# URL is not valid!
# Extracting from Comparison_of_Nvidia_chipsets
#
# (4, 11)
# Extracting from List_of_Nvidia_graphics_processing_units
#
# (11, 18)
# Extracting from Comparison_of_TLS_implementations
#
# (35, 16)
# Extracting from Comparison_of_antivirus_software
#
# (56, 25)
# Extracting from Comparison_of_email_clients
#
# (57, 5)
# Extracting from Comparison_of_integrated_development_environments
#
# (5, 12)
# Extracting from Comparison_of_layout_engines_(XHTML_1.1)
#
# (8, 2)
# Extracting from Comparison_of_operating_system_kernels
#
# (28, 15)

# %%
df_stats
# Out:
#                                                    URL nrows ncols
# 0               Comparison_between_Esperanto_and_Ido\n     4     6
# 1       Comparison_between_Esperanto_and_Interlingua\n     4     6
# 2            Comparison_between_Esperanto_and_Novial\n     0     2
# 3             Comparison_between_Ido_and_Interlingua\n     0     2
# 4                  Comparison_between_Ido_and_Novial\n     0     2
# 5    Comparison_between_U.S._states_and_countries_b...    51     4
# 6                     Comparison_of_ALGOL_68_and_C++\n     0     2
# 7                  Comparison_of_Afrikaans_and_Dutch\n   187     3
# 8       Comparison_of_Android_e-book_reader_software\n    16     4
# 9        Comparison_of_Asian_national_space_programs\n     0     7
# 10                 Comparison_of_Axis_&_Allies_games\n     4     6
# 11       Comparison_of_C_Sharp_and_Visual_Basic_.NET\n     5     1
# 12   Comparison_of_Chernobyl_and_other_radioactivit...     0     2
# 13             Comparison_of_Hokkien_writing_systems\n    28     1
# 14   Comparison_of_Home_Owners'_and_Civic_Associati...     4     6
# 15   Comparison_of_IOC,_FIFA,_and_ISO_3166_country_...     0     2
# 16                        Comparison_of_Java_and_C++\n    10    12
# 17                 Comparison_of_Linux_distributions\n     4     6
# 18      Comparison_of_MD_and_DO_in_the_United_States\n     4     6
# 19              Comparison_of_Portuguese_and_Spanish\n     0     2
# 20                     Comparison_of_Symbian_devices\n     0     2
# 21   Comparison_of_United_States_presidential_candi...    16     4
# 22                   Comparison_of_World_War_I_tanks\n     0     2
# 23               Comparison_of_browser_synchronizers\n    31    16
# 24       Comparison_of_business_integration_software\n    34     8
# 25                     Comparison_of_domestic_robots\n     0     2
# 26                      Comparison_of_e-book_formats\n     1     2
# 27                      Comparison_of_e-book_readers\n    59    20
# 28               Comparison_of_file_hosting_services\n     0     2
# 29   Comparison_of_layout_engines_(Cascading_Style_...     0     2
# ..                                                 ...   ...   ...
# 282                       Comparison_of_ADC_software\n     4     6
# 283                     Comparison_of_file_archivers\n    33     6
# 284                      Comparison_of_file_managers\n    51     6
# 285         Comparison_of_iOS_e-book_reader_software\n    21    13
# 286       Comparison_of_open-source_wireless_drivers\n     0     2
# 287             Comparison_of_portable_media_players\n     0     2
# 288                 Comparison_of_BitTorrent_clients\n    44    12
# 289                       Comparison_of_HTML_editors\n    41     5
# 290  Comparison_of_layout_engines_(Document_Object_...     0     2
# 291                       Comparison_of_mail_servers\n    44    18
# 292        Comparison_of_Internet_Relay_Chat_clients\n     0     2
# 293                           Comparison_of_alcopops\n     0     2
# 294  Comparison_of_geographic_information_systems_s...    42    10
# 295          Comparison_of_instant_messaging_clients\n     4     6
# 296            Comparison_of_raster_graphics_editors\n     4     6
# 297         Comparison_of_Microsoft_Windows_versions\n     5     9
# 298              Comparison_of_audio_player_software\n    54    20
# 299              Comparison_of_layout_engines_(HTML)\n     0     2
# 300      Comparison_of_open-source_operating_systems\n    30     8
# 301  Comparison_of_programming_languages_(basic_ins...     0     2
# 302            List_of_AMD_graphics_processing_units\n    22    16
# 303          List_of_Intel_graphics_processing_units\n     7    17
# 304                    Comparison_of_Nvidia_chipsets\n     4    11
# 305         List_of_Nvidia_graphics_processing_units\n    11    18
# 306                Comparison_of_TLS_implementations\n    35    16
# 307                 Comparison_of_antivirus_software\n    56    25
# 308                      Comparison_of_email_clients\n    57     5
# 309  Comparison_of_integrated_development_environme...     5    12
# 310         Comparison_of_layout_engines_(XHTML_1.1)\n     8     2
# 311           Comparison_of_operating_system_kernels\n    28    15
#
# [312 rows x 3 columns]

# %%
df_stats['nrows'].max(), df_stats['ncols'].max()
# Out:
# (981, 1473)

# %%
df_stats.loc[df_stats['ncols'].apply(pd.to_numeric, errors = 'coerce').idxmax()]['URL'] # TODO: troubles with argmax
# Out:
# 'Comparison_between_U.S._states_and_countries_by_GDP_(nominal)\n'
