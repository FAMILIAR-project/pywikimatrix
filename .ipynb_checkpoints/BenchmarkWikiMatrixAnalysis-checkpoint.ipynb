# %%
import os 
import re
import string


# in each folder there is a .tar.gz filename containing CSV files and called: 
COMPRESSED_FILENAME="outputCSVs"

### datasets 
GR1_HTML="output_MIAGE/PDL_2018-2019_GR1/output/html/"
GR1_WIKI="output_MIAGE/PDL_2018-2019_GR1/output/wikitext/"

GR2_HTML="output_MIAGE/PDL_2018-2019_GR2/output/html/"
GR2_WIKI="output_MIAGE/PDL_2018-2019_GR2/output/wikitext/"

GR3_HTML="output_MIAGE/PDL_2018-2019_GR3/output/html/"
GR3_WIKI="output_MIAGE/PDL_2018-2019_GR3/output/wikitext/"

GR4_HTML="output_MIAGE/PDL_2018-2019_GR4/output/html/"
GR4_WIKI="output_MIAGE/PDL_2018-2019_GR4/output/wikitext/"

GR5_HTML="output_MIAGE/PDL_1819_grp5/html/"
GR5_WIKI="output_MIAGE/PDL_1819_grp5/wikitext/"

GR6_HTML="output_MIAGE/PDL_2018_2019_GR6/output/html/"
GR6_WIKI="output_MIAGE/PDL_2018_2019_GR6/output/wiki/"

GR7_HTML="output_MIAGE/pdl-wiki/output/html/"
GR7_WIKI="output_MIAGE/pdl-wiki/output/wikitext/"

GR8_HTML="output_MIAGE/PDLProject/output/html/" 
GR8_WIKI="output_MIAGE/PDLProject/output/wikitext/"


# CSV-separator problem
# workaround to describe the ad-hoc solution describe here https://twitter.com/acherm/status/1084796917018697735 
# separator is defined at the end, depending on cell values
def csv_sep_detection(filename):
    sep_candidates = [',', ';', ':', '|', '-']
    document_text = open(filename, 'r')
    # originally document_text.read() for the whole file
    # but empirically there are many cases for which ',' frequently occurs despite non-being a separator
    # so instead just looking at the first line is very effective 
    text_string = document_text.readline() 
    
    occ_sep = map(text_string.count, sep_candidates) 
    list_occ_sep = list(occ_sep)
    return sep_candidates[list_occ_sep.index(max(list_occ_sep))]
    
#print(csv_sep_detection(GR1_HTML + "Comparison_of_movie_cameras-2.csv"))
#print(csv_sep_detection(GR1_HTML + "Comparison_of_memory_cards-3.csv"))
#print(csv_sep_detection(GR1_HTML + "Comparison_of_mobile_operating_systems-2.csv"))

# %%
import tarfile

# utility function used to compress CSV files (no longer useful now)
def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

#make_tarfile(GR1_HTML + COMPRESSED_FILENAME + ".tar.gz", GR1_HTML)

# remove all CSV files in a directory
# typically when untar the archive, we want to clean up once the process is finished 
def clean_CSV_files(source_dir):
    filelist = [ f for f in os.listdir(source_dir) if f.endswith(".csv") ]
    for f in filelist:
        os.remove(os.path.join(source_dir, f))
        
#clean_CSV_files(GR1_HTML) #

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def compute_frequency_colval(all_columns, all_vals):
    flatten = lambda l: [item for sublist in l for item in sublist]
    cols = flatten(all_columns)
    vals = flatten(flatten(all_vals))
    # "0" is to access to frequency values of value_counts
    wordfreq_cols = pd.DataFrame(cols)[0].value_counts() #[(w, cols.count(w)) for w in cols]
    wordfreq_vals = pd.DataFrame(vals)[0].value_counts() #[(w, cols.count(w)) for w in rows]
    return  wordfreq_cols, wordfreq_vals

def plot_frequency_colval(wordfreq_cols, wordfreq_vals, group_name):
    freq_col = pd.DataFrame(wordfreq_cols).rename(columns={0: "frequency"})
    freq_col['columnname'] = freq_col.index
    freq_vals = pd.DataFrame(wordfreq_vals).rename(columns={0: "frequency"})
    freq_vals['columnname'] = freq_vals.index
    #freq_col = pd.DataFrame(wordfreq_cols, columns=["columnname", "frequency"])
    wnoise_freq_col = freq_col[freq_col["columnname"].str.startswith("Unnamed") == False]
    #freq_col.sort_values(by="frequency", ascending=False)[:100].plot.bar(x="columnname", y="frequency", figsize=(20, 20))
    
    plt.style.use('ggplot')
    plt.rcParams.update({'font.size': 18})
    
    
    plt.figure()    
    wnoise_freq_col.sort_values(by="frequency", ascending=False)[:20].plot.barh(x="columnname", y="frequency", figsize=(20, 20), title="Frequency occurences of columns (" + group_name + ")")
    plt.gca().invert_yaxis()
    plt.savefig(str(group_name) + "-freqcolumns" + ".png")
    plt.show()
    
    # wnoise_freq_vals = freq_vals[freq_vals["columnname"].str.startswith("Unnamed") == False]
    #freq_rows.sort_values(by="frequency", ascending=False)[:100].plot.bar(x="columnname", y="frequency", figsize=(20, 20))
    plt.figure()
    freq_vals.sort_values(by="frequency", ascending=False)[:20].plot.barh(x="columnname", y="frequency", figsize=(20, 20), title="Frequency occurences of values (" + group_name + ")")
    plt.gca().invert_yaxis()
    plt.savefig(str(group_name) + "-freqvals" + ".png")
    plt.show()
    



#### procedure for analyzing CSV files extracted from Wikipedia (post-process)
### we assume there are CSV files in output_folder
def analysis_csvs(output_folder, sep=",", encoding=None):
    all_columns = [] 
    all_vals = []
    cols_stats = ["URL", "nrows", "ncols"]
    df_stats = pd.DataFrame(columns=cols_stats)
    parser_errors = []
    for filename in os.listdir(output_folder):
        if filename.endswith(".csv"): 
            try:
                if sep == 'auto':
                    rsep = csv_sep_detection(output_folder + filename)
                else:
                    rsep = sep
                df = pd.read_csv(output_folder + filename, sep=rsep, encoding=encoding)
            except Exception as e:
                parser_errors.append("Unable to parse" + str(filename) + str(e))
                continue

            nrow = int(df.shape[0])
            ncol = int(df.shape[1])
            vals = [filename, df.shape[0], df.shape[1]]
            df_stats = df_stats.append(dict(zip(cols_stats, vals)), ignore_index=True)
            if (nrow > 1 and ncol > 1):
                all_columns.append(df.columns.values)
                all_vals.append(df.reset_index(drop=True).values.tolist()) # (we should exclude index) # index.values)
        else:
            continue
    
    return df_stats, parser_errors, all_columns, all_vals 


#df_stats_base_line = analysis_csvs("output/", ",")
#df_stats_gr10 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDLProject/output/html/", ";")
#df_stats_gr6 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018_2019_GR6/output/html/", ",")
#df_stats_gr2 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/", sep=";", encoding="iso8859_15")
#df_stats_gr4 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR4/output/html/", sep=";")
#df_stats_gr1 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR1/output/html/", sep="auto")
#df_stats_gr5 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_1819_grp5/html/")
#df_stats_gr7 = analysis_csvs("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/pdl-wiki/output/html/",sep=",")

# global variables, quite weird 
df_errors = pd.DataFrame(columns=["group", "nerror"])

def process_morph_group(location_group, group_name, sep=",", encoding=None):    
    print ("Processing output CSVs of", group_name)
    print ("###########")
    
    # no longer needed
    # make_tarfile(location_group + COMPRESSED_FILENAME + ".tar.gz", location_group)
    # clean_CSV_files(location_group)
    
    # we untar the archive for getting CSV files 
    fname = location_group + COMPRESSED_FILENAME + ".tar.gz"
    print(fname)
    tarf = tarfile.open(fname)
    tarf.extractall(path=location_group)
    tarf.close()
    
    df_stats_gr, parser_errors, all_columns, all_vals = analysis_csvs(location_group, sep=sep, encoding=encoding)
    ######## collecting stats about columns and values
    wordfreq_cols, wordfreq_vals = compute_frequency_colval(all_columns, all_vals)  
    ######### plotting frequency of columns and values
    plot_frequency_colval(wordfreq_cols, wordfreq_vals, group_name)
    nerrors = len(parser_errors)
    print ("\t\t number of CSV parsing errors", str(nerrors))
    df_errors.loc[len(df_errors.index)] = (group_name, nerrors)
    # verbose print ("Errors:", parser_errors)
    print ("\n\n")
    
    # we clean up CSV files
    clean_CSV_files(location_group)
    
    return df_stats_gr

def extract_table_number_name(url):
    m = re.search("-(\d+).csv", url)
    if (m is None):
        return -1
    return m.group(1)

def aligne_table_names_gr8(df_stats):
    rurl = []
    for url in df_stats['URL']:
        n = int(extract_table_number_name(url))
        nurl = re.sub("-(\d+).csv", "-" + str(n + 1) + ".csv", url)
        rurl.append(nurl)    
    df_stats['URL'] = rurl

    


df_stats_baseline_html = process_morph_group("output/", group_name="pandas baseline", sep=",")



 
# groupe 8 is so-called "group 10" (it's really the 8th)
df_stats_gr8_html = process_morph_group(GR8_HTML, group_name="group 8", sep=";")
df_stats_gr8_wiki = process_morph_group(GR8_WIKI, group_name="group 8 wikitext", sep=";")
# very specific to group 8: they have started with "0" as an increment for naming files (instead of 1)
aligne_table_names_gr8(df_stats_gr8_html)
aligne_table_names_gr8(df_stats_gr8_wiki)
    

df_stats_gr6_html = process_morph_group(GR6_HTML, group_name="group 6", sep=",")
df_stats_gr6_wiki = process_morph_group(GR6_WIKI, group_name="group 6 wikitext", sep=",")


df_stats_gr2_html = process_morph_group(GR2_HTML, group_name="group 2", sep=";", encoding="iso8859_15")
df_stats_gr2_wiki = process_morph_group(GR2_WIKI, group_name="group 2 wikitext", sep=";", encoding="iso8859_15")

df_stats_gr4_html = process_morph_group(GR4_HTML, group_name="group 4", sep=";")
df_stats_gr4_wiki = process_morph_group(GR4_WIKI, group_name="group 4 wikitext", sep=";")


df_stats_gr1_html = process_morph_group(GR1_HTML, group_name="group 1", sep="auto")
df_stats_gr1_wiki = process_morph_group(GR1_WIKI, group_name="group 1 wikitext", sep="auto")


df_stats_gr5_html = process_morph_group(GR5_HTML, group_name="group 5")
df_stats_gr5_wiki = process_morph_group(GR5_WIKI, group_name="group 5 wikitext")


df_stats_gr3_html = process_morph_group(GR3_HTML, group_name="group 3")
# badly immplemented here
df_stats_gr3_wiki = process_morph_group(GR3_WIKI, group_name="group 3 wikitext")


df_stats_gr7_html = process_morph_group(GR7_HTML, group_name="group 7", sep=",")
df_stats_gr7_wiki = process_morph_group(GR7_WIKI, group_name="group 7 wikitext", sep=",")
# Out:
# Processing output CSVs of pandas baseline
# ###########
# output/outputCSVs.tar.gz
# 		 number of CSV parsing errors 0
#
#
#
# Processing output CSVs of group 8
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDLProject/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 11
#
#
#
# Processing output CSVs of group 8 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDLProject/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 32
#
#
#
# Processing output CSVs of group 6
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018_2019_GR6/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 33
#
#
#
# Processing output CSVs of group 6 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018_2019_GR6/output/wiki/outputCSVs.tar.gz
# 		 number of CSV parsing errors 147
#
#
#
# Processing output CSVs of group 2
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 546
#
#
#
# Processing output CSVs of group 2 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 419
#
#
#
# Processing output CSVs of group 4
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR4/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 53
#
#
#
# Processing output CSVs of group 4 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR4/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 96
#
#
#
# Processing output CSVs of group 1
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR1/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 32
#
#
#
# Processing output CSVs of group 1 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR1/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 60
#
#
#
# Processing output CSVs of group 5
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_1819_grp5/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 55
#
#
#
# Processing output CSVs of group 5 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_1819_grp5/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 44
#
#
#
# Processing output CSVs of group 3
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR3/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 9
#
#
#
# Processing output CSVs of group 3 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR3/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 747
#
#
#
# Processing output CSVs of group 7
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/pdl-wiki/output/html/outputCSVs.tar.gz
# 		 number of CSV parsing errors 367
#
#
#
# Processing output CSVs of group 7 wikitext
# ###########
# /Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/pdl-wiki/output/wikitext/outputCSVs.tar.gz
# 		 number of CSV parsing errors 255

# %%
df_errors
# Out:
#                group nerror
# 0    pandas baseline      0
# 1            group 8     11
# 2   group 8 wikitext     32
# 3            group 6     33
# 4   group 6 wikitext    147
# 5            group 2    546
# 6   group 2 wikitext    419
# 7            group 4     53
# 8   group 4 wikitext     96
# 9            group 1     32
# 10  group 1 wikitext     60
# 11           group 5     55
# 12  group 5 wikitext     44
# 13           group 3      9
# 14  group 3 wikitext    747
# 15           group 7    367
# 16  group 7 wikitext    255

# %%
def process_gr_stats(df_stats_gr_html, df_stats_gr_wiki):
    print(df_stats_gr_html.shape, df_stats_gr_wiki.shape)
    plt.figure()
    df_stats_gr_html['nrows'].plot.hist(color = 'teal')
    df_stats_gr_wiki['nrows'].plot.hist(alpha = 0.5,  color = 'red')
    plt.show()
    plt.figure()
    df_stats_gr_wiki['ncols'].plot.hist(color = 'red', alpha = 0.5)
    df_stats_gr_html['ncols'].plot.hist(color = 'blue')
    plt.show()
    plt.figure()
    df_stats_gr_wiki['ncols'].plot.box()
    plt.show()
    plt.figure()
    df_stats_gr_html['ncols'].plot.box()
    plt.show()
    print(df_stats_gr6_html.sort_values(by="nrows", ascending=False)[:10])
    print(df_stats_gr6_wiki.sort_values(by="nrows", ascending=False)[:10])
    
process_gr_stats(df_stats_gr1_html, df_stats_gr1_wiki)
# Out:
# (1587, 3) (1340, 3)
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
#                                                    URL nrows ncols
# 641  Comparison_of_Dewey_and_Library_of_Congress_su...   456     3
# 715  Comparison_of_IOC,_FIFA,_and_ISO_3166_country_...   254     6
# 497          Comparison_of_graphics_file_formats-1.csv   245     8
# 397  Comparison_between_U.S._states_and_countries_b...   241     3
# 188  Comparison_between_Argentine_provinces_and_cou...   207     3
# 834  Comparison_of_massively_multiplayer_online_rol...   199     9
# 52             Comparison_of_Afrikaans_and_Dutch-1.csv   188     3
# 131                Comparison_of_Symbian_devices-1.csv   162     9
# 783           Comparison_of_XMPP_server_software-2.csv   139    13
# 247         Comparison_of_Portuguese_and_Spanish-3.csv   139     4
#                                                    URL nrows ncols
# 521  Comparison_of_Dewey_and_Library_of_Congress_su...   456     3
# 399          Comparison_of_graphics_file_formats-1.csv   245     8
# 719  Comparison_between_U.S._states_and_countries_b...   244     1
# 168  Comparison_between_Argentine_provinces_and_cou...   207     3
# 738  Comparison_between_U.S._states_and_countries_b...   193     1
# 48             Comparison_of_Afrikaans_and_Dutch-1.csv   188     3
# 118                Comparison_of_Symbian_devices-1.csv   162     9
# 639           Comparison_of_XMPP_server_software-2.csv   139    13
# 212         Comparison_of_Portuguese_and_Spanish-3.csv   139     4
# 583    Comparison_of_project_management_software-1.csv   135     6

# %%
def get_freqs(location_group, group_name, sep=",", encoding=None): 
     # we untar the archive for getting CSV files 
    fname = location_group + COMPRESSED_FILENAME + ".tar.gz"
    tarf = tarfile.open(fname)
    tarf.extractall(path=location_group)
    tarf.close()
    
    df_stats_gr, parser_errors, all_columns, all_vals = analysis_csvs(location_group, sep=sep, encoding=encoding)
    ######## collecting stats about columns and values
    wordfreq_cols, wordfreq_vals = compute_frequency_colval(all_columns, all_vals)  
    
    # we are done: we can clean up CSV files
    clean_CSV_files(location_group)
    
    return wordfreq_cols, wordfreq_vals

def compare_wikihtml (html_location, wiki_location, group_name, sep):
    wordfreq_cols_gr_html, wordfreq_vals_gr_html = get_freqs(html_location, group_name=group_name, sep=sep)
    wordfreq_cols_gr_wiki, wordfreq_vals_gr_wiki = get_freqs(wiki_location, group_name=group_name, sep=sep)
    
    dfr = pd.DataFrame()    
    dfr['html'] = pd.DataFrame(wordfreq_cols_gr_html)[0]
   
    dfr['wiki'] = pd.DataFrame(wordfreq_cols_gr_wiki)[0]
    dfr = dfr[dfr['wiki'].index.str.startswith("Unnamed") == False]
    dfr = dfr[dfr['html'].index.str.startswith("Unnamed") == False]
    #wordfreq_cols_gr1_wiki
    return dfr

    
#dfr1 = compare_wikihtml("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR1/output/html/", "/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR1/output/wikitext/", group_name="group 1", sep="auto") 
#dfr1.sort_values(by="html", ascending=False)[1:10]

dfr3 = compare_wikihtml(GR3_HTML, GR3_WIKI, group_name="group 3", sep=",")
#dfr3.sort_values(by="wiki", ascending=False)[1:10]


dfr8 = compare_wikihtml(GR8_HTML, GR8_WIKI, group_name="group 8", sep=";")
#dfr8.sort_values(by="html", ascending=False)[0:10]

def plot_comparison_wikihtml(dfr, by="html"):
    plt.style.use('ggplot')
    plt.rcParams.update({'font.size': 18})
    
    fig = plt.figure(figsize=(14, 8))
    ax = fig.add_subplot(111) # Create matplotlib axes
    ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
    width=0.3
    
    dfr.sort_values(by=by, ascending=False)[:10].plot.barh(y="html", color="xkcd:red", width=width, ax=ax2, position=1)
    dfr.sort_values(by=by, ascending=False)[:10].plot.barh(y="wiki", color="xkcd:blue", width=width, ax=ax2, position=0)
    ax2.invert_yaxis()
    plt.savefig("worst-comparisonwikihtml-by" + by + ".png") # TODO
    plt.show()

# good
#plot_comparison_wikihtml(dfr8, by="wiki")
#plot_comparison_wikihtml(dfr8, by="html")
# worst
plot_comparison_wikihtml(dfr3, by="wiki")
plot_comparison_wikihtml(dfr3, by="html")

# dfr3.sort_values(by="html", ascending=False)[1:10]

# %%
from functools import reduce
df_merged = reduce(lambda  left,right: pd.merge(left, right, how="outer", on=['URL']), [df_stats_baseline_html, df_stats_gr1_html, df_stats_gr2_html, df_stats_gr3_html, df_stats_gr4_html, df_stats_gr5_html, df_stats_gr6_html, df_stats_gr7_html, df_stats_gr8_html])
df_merged.sort_values(by="URL")

df_merged.columns = ['URL', 'nrows_baseline', 'ncols_baseline', 'nrows_1', 'ncols_1', 'nrows_2', 'ncols_2',
       'nrows_3', 'ncols_3', 'nrows_4', 'ncols_4', 'nrows_5', 'ncols_5',
       'nrows_6', 'ncols_6', 'nrows_7', 'ncols_7', 'nrows_8', 'ncols_8']

clean_df_merged = df_merged[(df_merged['URL'] == 'companies.csv') == False]
#clean_df_merged.sort_values(by="nrows_baseline", ascending=False)

clean_df_merged.sort_values(by="URL", ascending=False)[:50]
# Out:
#                                                     URL nrows_baseline  \
# 2558      Évolution de la population [ modifier ]-1.csv            NaN
# 2557  Évolution de la population [ modifier ], suite...            NaN
# 2549  Évolution de la population [ modifier ], suite...            NaN
# 2556  Évolution de la population [ modifier ], suite...            NaN
# 2808       Software development effort estimation-2.csv            NaN
# 2880       Software development effort estimation-1.csv            NaN
# 2960                                   MUD client-3.csv            NaN
# 2916                                   MUD client-2.csv            NaN
# 2969                                   MUD client-1.csv            NaN
# 4400    List_of_Nvidia_graphics_processing_units-91.csv            NaN
# 1316    List_of_Nvidia_graphics_processing_units-90.csv              1
# 2460     List_of_Nvidia_graphics_processing_units-9.csv             18
# 1131    List_of_Nvidia_graphics_processing_units-89.csv              5
# 1138    List_of_Nvidia_graphics_processing_units-88.csv              5
# 1489    List_of_Nvidia_graphics_processing_units-87.csv             13
# 1483    List_of_Nvidia_graphics_processing_units-86.csv              2
# 1307    List_of_Nvidia_graphics_processing_units-85.csv              7
# 1310    List_of_Nvidia_graphics_processing_units-84.csv              1
# 1643    List_of_Nvidia_graphics_processing_units-83.csv              7
# 1658    List_of_Nvidia_graphics_processing_units-82.csv             15
# 1822    List_of_Nvidia_graphics_processing_units-81.csv             73
# 1810    List_of_Nvidia_graphics_processing_units-80.csv              4
# 2485     List_of_Nvidia_graphics_processing_units-8.csv             23
# 1468    List_of_Nvidia_graphics_processing_units-79.csv              0
# 3897   List_of_Nvidia_graphics_processing_units-781.csv            NaN
# 1506    List_of_Nvidia_graphics_processing_units-78.csv              5
# 4795   List_of_Nvidia_graphics_processing_units-771.csv            NaN
# 1154    List_of_Nvidia_graphics_processing_units-77.csv              7
# 4993   List_of_Nvidia_graphics_processing_units-761.csv            NaN
# 1117    List_of_Nvidia_graphics_processing_units-76.csv             11
# 3626   List_of_Nvidia_graphics_processing_units-751.csv            NaN
# 965     List_of_Nvidia_graphics_processing_units-75.csv              4
# 3997   List_of_Nvidia_graphics_processing_units-741.csv            NaN
# 993     List_of_Nvidia_graphics_processing_units-74.csv              5
# 4099   List_of_Nvidia_graphics_processing_units-731.csv            NaN
# 621     List_of_Nvidia_graphics_processing_units-73.csv              2
# 4265   List_of_Nvidia_graphics_processing_units-721.csv            NaN
# 647     List_of_Nvidia_graphics_processing_units-72.csv              5
# 4526   List_of_Nvidia_graphics_processing_units-711.csv            NaN
# 809     List_of_Nvidia_graphics_processing_units-71.csv              8
# 4537   List_of_Nvidia_graphics_processing_units-701.csv            NaN
# 793     List_of_Nvidia_graphics_processing_units-70.csv              2
# 224      List_of_Nvidia_graphics_processing_units-7.csv             26
# 4039   List_of_Nvidia_graphics_processing_units-691.csv            NaN
# 1664    List_of_Nvidia_graphics_processing_units-69.csv              8
# 4325   List_of_Nvidia_graphics_processing_units-681.csv            NaN
# 1640    List_of_Nvidia_graphics_processing_units-68.csv              7
# 4480   List_of_Nvidia_graphics_processing_units-671.csv            NaN
# 623     List_of_Nvidia_graphics_processing_units-67.csv              8
# 4574   List_of_Nvidia_graphics_processing_units-661.csv            NaN
#
#      ncols_baseline nrows_1 ncols_1 nrows_2 ncols_2 nrows_3 ncols_3 nrows_4  \
# 2558            NaN       1       9     NaN     NaN     NaN     NaN     NaN
# 2557            NaN       1       9     NaN     NaN     NaN     NaN     NaN
# 2549            NaN       1       9     NaN     NaN     NaN     NaN     NaN
# 2556            NaN       1       9     NaN     NaN     NaN     NaN     NaN
# 2808            NaN     NaN     NaN     NaN     NaN       4      10     NaN
# 2880            NaN     NaN     NaN     NaN     NaN       7       3     NaN
# 2960            NaN     NaN     NaN     NaN     NaN      31      12     NaN
# 2916            NaN     NaN     NaN     NaN     NaN      32      13     NaN
# 2969            NaN     NaN     NaN     NaN     NaN      32       8     NaN
# 4400            NaN     NaN     NaN     NaN     NaN     NaN     NaN      29
# 1316              3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2460              6       6      20     NaN     NaN     NaN     NaN     NaN
# 1131              6     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1138              3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1489             14     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1483              3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1307              8     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1310              3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1643              7     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1658             14     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1822             16     NaN     NaN     NaN     NaN     NaN     NaN      18
# 1810             21     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2485             17      12       9     NaN     NaN     NaN     NaN     NaN
# 1468              3       7      20     NaN     NaN     NaN     NaN     NaN
# 3897            NaN     NaN     NaN     NaN     NaN     NaN     NaN       4
# 1506              9      10      22     NaN     NaN     NaN     NaN     NaN
# 4795            NaN     NaN     NaN     NaN     NaN     NaN     NaN       5
# 1154             20       8      19     NaN     NaN     NaN     NaN     NaN
# 4993            NaN     NaN     NaN     NaN     NaN     NaN     NaN       7
# 1117             20      24      27     NaN     NaN     NaN     NaN     NaN
# 3626            NaN     NaN     NaN     NaN     NaN     NaN     NaN      11
# 965              21       6      19     NaN     NaN     NaN     NaN     NaN
# 3997            NaN     NaN     NaN     NaN     NaN     NaN     NaN       4
# 993              21      29      28     NaN     NaN     NaN     NaN     NaN
# 4099            NaN     NaN     NaN     NaN     NaN     NaN     NaN       5
# 621              20       7      19     NaN     NaN     NaN     NaN     NaN
# 4265            NaN     NaN     NaN     NaN     NaN     NaN     NaN       2
# 647              21      18      26     NaN     NaN     NaN     NaN     NaN
# 4526            NaN     NaN     NaN     NaN     NaN     NaN     NaN       5
# 809              21       5      19     NaN     NaN     NaN     NaN      23
# 4537            NaN     NaN     NaN     NaN     NaN     NaN     NaN       8
# 793              21       5      19     NaN     NaN     NaN     NaN     NaN
# 224              17      18      22     NaN     NaN     NaN     NaN     NaN
# 4039            NaN     NaN     NaN     NaN     NaN     NaN     NaN       2
# 1664             21       7      19     NaN     NaN     NaN     NaN     NaN
# 4325            NaN     NaN     NaN     NaN     NaN     NaN     NaN       8
# 1640             21      39      19     NaN     NaN     NaN     NaN     NaN
# 4480            NaN     NaN     NaN     NaN     NaN     NaN     NaN       7
# 623              20       7      19     NaN     NaN     NaN     NaN     NaN
# 4574            NaN     NaN     NaN     NaN     NaN     NaN     NaN       8
#
#      ncols_4 nrows_5 ncols_5 nrows_6 ncols_6 nrows_7 ncols_7 nrows_8 ncols_8
# 2558     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2557     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2549     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2556     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2808     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2880     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2960     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2916     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2969     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4400      17     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1316     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2460     NaN       7      19     NaN     NaN      16       4     NaN     NaN
# 1131     NaN     NaN     NaN     NaN     NaN       2       3     NaN     NaN
# 1138     NaN     NaN     NaN     NaN     NaN       4       1     NaN     NaN
# 1489     NaN     NaN     NaN     NaN     NaN       6       7     NaN     NaN
# 1483     NaN     NaN     NaN     NaN     NaN       1       1     NaN     NaN
# 1307     NaN     NaN     NaN     NaN     NaN       3       4     NaN     NaN
# 1310     NaN     NaN     NaN     NaN     NaN       0       1     NaN     NaN
# 1643     NaN     NaN     NaN     NaN     NaN       4       1     NaN     NaN
# 1658     NaN     NaN     NaN     NaN     NaN       6       7     NaN     NaN
# 1822       8     NaN     NaN     NaN     NaN      24       8     NaN     NaN
# 1810     NaN     NaN     NaN     NaN     NaN       2      19     NaN     NaN
# 2485     NaN       8      16     NaN     NaN      19      15     NaN     NaN
# 1468     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3897      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1506     NaN       4      23     NaN     NaN       3       7     NaN     NaN
# 4795       9     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1154     NaN       7      19     NaN     NaN       5      18     NaN     NaN
# 4993      20     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1117     NaN      16      20     NaN     NaN       9      18     NaN     NaN
# 3626      20     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 965      NaN       6      20     NaN     NaN       2      19     NaN     NaN
# 3997      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 993      NaN      10      20     NaN     NaN       3      19     NaN     NaN
# 4099      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 621      NaN       6      19     NaN     NaN       0      18     NaN     NaN
# 4265      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 647      NaN       2      23     NaN     NaN       3      19     NaN     NaN
# 4526      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 809       17       8      20     NaN     NaN       6      19     NaN     NaN
# 4537      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 793      NaN      24      27     NaN     NaN       0      19     NaN     NaN
# 224      NaN       9      16     NaN     NaN      22      15     NaN     NaN
# 4039      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1664     NaN      21       7     NaN     NaN       6      19     NaN     NaN
# 4325      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1640     NaN       5      20     NaN     NaN       5      19     NaN     NaN
# 4480      21     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 623      NaN       5      19     NaN     NaN       6      18     NaN     NaN
# 4574      20     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN

# %%
# .rename(columns={0 : "html"}
df_stats_baseline_html.sort_values(by="URL", ascending=False)
df_stats_gr1_html[df_stats_gr1_html['URL'].str.contains("3D")]

print(df_stats_gr8_html[df_stats_gr8_html['URL'].str.contains("FIFA")]['URL'].values)
print(df_stats_baseline_html[df_stats_baseline_html['URL'].str.contains("FIFA")]['URL'].values)
# Out:
# ['Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-1.csv'
#  'Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-2.csv']
# ['Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-5.csv'
#  'Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-4.csv'
#  'Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-3.csv'
#  'Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-2.csv'
#  'Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-1.csv']

# %%
#df_merged[df_merged['URL'].str.contains("3D")]
df_merged['covering'] = df_merged.isnull().sum(axis=1)
#df_merged.sort_values(by="covering", ascending=True)[:10]

df_merged.sort_values(by="nrows_8", ascending=False)[:10]
#df_stats_gr8_html.sort_values(by="nrows", ascending=False)[:10]
# Out:
#                                                     URL nrows_baseline  \
# 1888  Comparison_of_IOC,_FIFA,_and_ISO_3166_country_...              0
# 1242          Comparison_of_graphics_file_formats-1.csv            245
# 2264  Comparison_between_U.S._states_and_countries_b...            192
# 1010  Comparison_between_U.S._states_and_countries_b...            241
# 471   Comparison_between_Argentine_provinces_and_cou...            207
# 2169  Comparison_of_massively_multiplayer_online_rol...              0
# 2339  Comparison_between_U.S._states_and_countries_b...             52
# 142             Comparison_of_Afrikaans_and_Dutch-1.csv            188
# 315                 Comparison_of_Symbian_devices-1.csv              0
# 2545     Comparison_of_data_serialization_formats-2.csv             57
#
#      ncols_baseline nrows_1 ncols_1 nrows_2 ncols_2 nrows_3 ncols_3 nrows_4  \
# 1888              3      23       5     254       7     NaN     NaN     NaN
# 1242              9      33      14     NaN     NaN     NaN     NaN     NaN
# 2264              4     192       3     243       4     NaN     NaN     NaN
# 1010              4       1       1     274       5     NaN     NaN     NaN
# 471               4     207       3     207       4     NaN     NaN     NaN
# 2169              3     199       9     NaN     NaN     NaN     NaN     NaN
# 2339              4      52       3     192       4     NaN     NaN     NaN
# 142               4      27       3     188       4     NaN     NaN     NaN
# 315               3     162       9     NaN     NaN     NaN     NaN     NaN
# 2545             12     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      ncols_4 nrows_5 ncols_5 nrows_6 ncols_6 nrows_7 ncols_7 nrows_8 ncols_8  \
# 1888     NaN     254       6     254       6     NaN     NaN     254       6
# 1242     NaN      33      14     245       8     243       7     245       8
# 2264     NaN     NaN     NaN     NaN     NaN     191       3     243       3
# 1010     NaN     NaN     NaN     241       3     NaN     NaN     241       3
# 471      NaN     NaN     NaN     207       3     NaN     NaN     207       3
# 2169     NaN     NaN     NaN     199       9     NaN     NaN     199       9
# 2339     NaN     NaN     NaN     NaN     NaN      50       3     192       3
# 142      NaN     188       3     188       3     187       3     188       3
# 315      NaN     NaN     NaN     162       9     NaN     NaN     162       9
# 2545     NaN     NaN     NaN      20       8      55      11     140       9
#
#       covering
# 1888         6
# 1242         6
# 2264         8
# 1010         8
# 471          8
# 2169        10
# 2339         8
# 142          4
# 315         10
# 2545        10

# %%
df_stats_gr6_html.sort_values(by="nrows", ascending=False)[:10]
# Out:
#                                                    URL nrows ncols
# 641  Comparison_of_Dewey_and_Library_of_Congress_su...   456     3
# 715  Comparison_of_IOC,_FIFA,_and_ISO_3166_country_...   254     6
# 497          Comparison_of_graphics_file_formats-1.csv   245     8
# 397  Comparison_between_U.S._states_and_countries_b...   241     3
# 188  Comparison_between_Argentine_provinces_and_cou...   207     3
# 834  Comparison_of_massively_multiplayer_online_rol...   199     9
# 52             Comparison_of_Afrikaans_and_Dutch-1.csv   188     3
# 131                Comparison_of_Symbian_devices-1.csv   162     9
# 783           Comparison_of_XMPP_server_software-2.csv   139    13
# 247         Comparison_of_Portuguese_and_Spanish-3.csv   139     4

# %%
df_stats_gr8_html.sort_values(by="nrows", ascending=False)[:10]
# Out:
#                                                    URL nrows ncols
# 659  Comparison_of_IOC,_FIFA,_and_ISO_3166_country_...   254     6
# 531          Comparison_of_graphics_file_formats-1.csv   245     8
# 895  Comparison_between_U.S._states_and_countries_b...   243     3
# 461  Comparison_between_U.S._states_and_countries_b...   241     3
# 189  Comparison_between_Argentine_provinces_and_cou...   207     3
# 807  Comparison_of_massively_multiplayer_online_rol...   199     9
# 963  Comparison_between_U.S._states_and_countries_b...   192     3
# 103            Comparison_of_Afrikaans_and_Dutch-1.csv   188     3
# 140                Comparison_of_Symbian_devices-1.csv   162     9
# 917     Comparison_of_data_serialization_formats-2.csv   140     9

# %%
df_stats_baseline_html[(df_stats_baseline_html['URL'] == 'companies.csv') == False].sort_values(by="nrows", ascending=False)[:10].style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >URL</th>
#         <th class="col_heading level0 col1" >nrows</th>
#         <th class="col_heading level0 col2" >ncols</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row0" class="row_heading level0 row0" >2510</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row0_col0" class="data row0 col0" >Comparison_between_U.S._states_and_countries_by_GDP_(nominal)-1.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row0_col1" class="data row0 col1" >981</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row0_col2" class="data row0 col2" >1474</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row1" class="row_heading level0 row1" >918</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row1_col0" class="data row1 col0" >Comparison_of_Malaysian_and_Indonesian-1.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row1_col1" class="data row1 col1" >593</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row1_col2" class="data row1 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row2" class="row_heading level0 row2" >1692</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row2_col0" class="data row2 col0" >Comparison_of_Dewey_and_Library_of_Congress_subject_classification-1.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row2_col1" class="data row2 col1" >456</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row2_col2" class="data row2 col2" >4</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row3" class="row_heading level0 row3" >1722</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row3_col0" class="data row3 col0" >Comparison_of_Chinese_romanization_systems-2.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row3_col1" class="data row3 col1" >413</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row3_col2" class="data row3 col2" >12</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row4" class="row_heading level0 row4" >83</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row4_col0" class="data row4 col0" >Comparison_of_layout_engines_(Cascading_Style_Sheets)-7.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row4_col1" class="data row4 col1" >402</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row4_col2" class="data row4 col2" >9</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row5" class="row_heading level0 row5" >2282</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row5_col0" class="data row5 col0" >Comparison_of_layout_engines_(Document_Object_Model)-6.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row5_col1" class="data row5 col1" >359</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row5_col2" class="data row5 col2" >9</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row6" class="row_heading level0 row6" >1713</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row6_col0" class="data row6 col0" >Comparison_of_IOC,_FIFA,_and_ISO_3166_country_codes-2.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row6_col1" class="data row6 col1" >254</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row6_col2" class="data row6 col2" >7</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row7" class="row_heading level0 row7" >1242</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row7_col0" class="data row7 col0" >Comparison_of_graphics_file_formats-1.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row7_col1" class="data row7 col1" >245</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row7_col2" class="data row7 col2" >9</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row8" class="row_heading level0 row8" >2032</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row8_col0" class="data row8 col0" >Comparison_between_U.S._states_and_countries_by_GDP_(nominal)-4.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row8_col1" class="data row8 col1" >243</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row8_col2" class="data row8 col2" >4</td>
#     </tr>    <tr>
#         <th id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0level0_row9" class="row_heading level0 row9" >1010</th>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row9_col0" class="data row9 col0" >Comparison_between_U.S._states_and_countries_by_GDP_(nominal)_per_capita-2.csv</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row9_col1" class="data row9 col1" >241</td>
#         <td id="T_c23a9d88_1da2_11e9_9da2_6a0001d158d0row9_col2" class="data row9 col2" >4</td>
#     </tr></tbody>
# </table>

# %%
print("Issues with CSV -- group 2")
# group 2 issue
# encoding needed! (utf8 not working)
# eg 
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/Comparison_of_handheld_game_consoles-1.csv", sep=";", encoding="iso8859_15")
# numerous problem remains eg here: 
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/List_of_Intel_graphics_processing_units-8.csv", sep=";", encoding="iso8859_15", error_bad_lines=False)
# some cell values contain the separator
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/Comparison_of_movie_cameras-2.csv", sep=";", encoding="iso8859_15", error_bad_lines=False)
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/Comparison_of_C_Sharp_and_Java-7.csv", sep=";", encoding="iso8859_15")
# no problem for this one:
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR2/output/html/Comparison_of_packet_analyzers-1.csv", sep=";", encoding="iso8859_15")
# Out:
# Issues with CSV -- group 2

# %%
print("Issues with CSV -- group 4")
# group 4 issue
# quote issue I guess
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR4/output/HTML/Comparison_of_Malaysian_and_Indonesian-01.csv", sep=";")
# complex table 
# pd.read_csv("/Users/macher1/Documents/SANDBOX/PDL1819-wikimatrix/PDL_2018-2019_GR4/output/HTML/Comparison_of_BitTorrent_clients-51.csv", sep=";")
# Out:
# Issues with CSV -- group 4

# %%
print ("Issues with CSV -- group 7")
# you need to untar before 
# CSV can be parsed but there is a problem with columns' names
# pd.read_csv(GR7_HTML + "Comparison_of_BitTorrent_clients-3.csv", sep=",")[:10]
# Out:
# Issues with CSV -- group 7
